# %% [markdown]
# <a href="https://colab.research.google.com/github/lageniaestela/12demayo/blob/master/bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gtts
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.5.0
#     Uninstalling click-8.5.0:
#       Successfully uninstalled click-8.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wandb 0.28.1 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# huggingface-hub 1.29.0 requires click<9.0.0,>=8.4.2, but you have click 8.1.8 which is incompatible.
# spacy 3.8.16 requires click<9.0.0,>=8.2.1, but you have click 8.1.8 which is incompatible.
# ...

# %%
# !pip install gtts

# %%
# !pip install librosa

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd

# ===== GENERACIÓN DE UNA SEÑAL DE VOZ =====
# Simulamos una señal grabada de voz (usamos un tono hablado generado con TTS)
from gtts import gTTS

tts = gTTS("Esta es una prueba de análisis espectral usando Fourier", lang="es")
tts.save("voz_fft.mp3")

# Cargar el archivo de audio generado
audio, sr = librosa.load("voz_fft.mp3")

# Reproducimos el audio
ipd.Audio("voz_fft.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd

from gtts import gTTS

tts = gTTS("Esta es una prueba de análisis espectral usando Fourier", lang="es")
tts.save("voz_fft.mp3")

# Cargar el archivo de audio generado
audio, sr = librosa.load("voz_fft.mp3")

# Reproducimos el audio
ipd.Audio("voz_fft.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 2.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.1.8
#     Uninstalling click-8.1.8:
#       Successfully uninstalled click-8.1.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gtts 2.5.4 requires click<8.2,>=7.1, but you have click 8.5.0 which is incompatible.
# ...

# %%
from transformers import pipeline

fill_mask = pipeline("fill-mask", model="bert-base-uncased")


fill_mask("[MASK].")
# Out:
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# [transformers] BertForMaskedLM LOAD REPORT from: bert-base-uncased
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# cls.seq_relationship.weight | UNEXPECTED |  |
# bert.pooler.dense.bias      | UNEXPECTED |  |
# cls.seq_relationship.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight    | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'score': 0.19153834879398346,
#   'token': 13820,
#   'token_str': '##ido',
#   'sequence': 'las islas malvinas sonido.'},
#  {'score': 0.18360362946987152,
#   'token': 2891,
#   'token_str': '##os',
#   'sequence': 'las islas malvinas sonos.'},
#  {'score': 0.059035755693912506,
#   'token': 2080,
#   'token_str': '##o',
#   'sequence': 'las islas malvinas sono.'},
#  {'score': 0.057806842029094696,
#   'token': 28574,
#   'token_str': '##ando',
# ...

# %%
from transformers import pipeline

fill_mask = pipeline("fill-mask", model="dccuchile/bert-base-spanish-wwm-cased")


fill_mask("Los islas Malvinas son [MASK].")
# Out:
# config.json:   0%|          | 0.00/648 [00:00<?, ?B/s]
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B /  440MB
# pytorch_model.bin: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/204 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/364 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/242k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/480k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  440MB
# model.safetensors: downloading bytes:           |  0.00B
# special_tokens_map.json:   0%|          | 0.00/134 [00:00<?, ?B/s]
# [{'score': 0.11354315280914307,
#   'token': 8493,
#   'token_str': 'islas',
#   'sequence': 'Los islas Malvinas son islas.'},
#  {'score': 0.03632180392742157,
#   'token': 30102,
#   'token_str': 'adyacentes',
#   'sequence': 'Los islas Malvinas son adyacentes.'},
#  {'score': 0.030131882056593895,
#   'token': 7012,
#   'token_str': 'similares',
# ...

# %%
# !pip install gTTS
# Out:
# ...
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# ...
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.5.0
#     Uninstalling click-8.5.0:
#       Successfully uninstalled click-8.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wandb 0.28.1 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# huggingface-hub 1.29.0 requires click<9.0.0,>=8.4.2, but you have click 8.1.8 which is incompatible.
# spacy 3.8.16 requires click<9.0.0,>=8.2.1, but you have click 8.1.8 which is incompatible.
# ...

# %%
from transformers import pipeline

# Cargar el modelo multilingüe o específico en español para análisis de sentimientos
@st.cache_resource
def load_sentiment_model():
    return pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

sentiment_analyzer = load_sentiment_model()

# Integración en Streamlit
st.subheader("❤️ Análisis de Sentimientos")
if st.button("Analizar Sentimiento del Texto"):
    if texto_usuario:
        resultado = sentiment_analyzer(texto_usuario)[0]
        # El modelo de nlptown clasifica de 1 a 5 estrellas
        label = resultado['label']
        score = resultado['score']

        st.write(f"**Resultado:** {label}")
        st.write(f"**Confianza:** {score:.4f}")
    else:
        st.warning("Por favor escribe una frase primero.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1159/3184232738.py in <cell line: 0>()
#       2
#       3 # Cargar el modelo multilingüe o específico en español para análisis de sentimientos
# ----> 4 @st.cache_resource
#       5 def load_sentiment_model():
#       6     return pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")
#
# NameError: name 'st' is not defined

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import IPython.display as ipd
from gtts import gTTS

tts = gTTS("Esta es una prueba de análisis espectral usando Fourier", lang="fr")
tts.save("voz_fft.mp3")

# Cargar el archivo de audio generado
audio, sr = librosa.load("voz_fft.mp3")

# Reproducimos el audio
ipd.Audio("voz_fft.mp3")

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Cargar un archivo de audio de ejemplo (reemplaza con tu archivo o usa uno de librosa)
audio_path = librosa.ex('nutcracker')
audio, sr = librosa.load(audio_path)

# ANÁLISIS DE ESPECTRO CON FFT
D = librosa.amplitude_to_db(np.abs(librosa.stft(audio)), ref=np.max)

plt.figure(figsize=(10, 4))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log', cmap='magma')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de voz - FFT')
plt.tight_layout()
plt.show()
