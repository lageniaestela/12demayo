# %% [markdown]
# <a href="https://colab.research.google.com/github/lageniaestela/12demayo/blob/master/Lena2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy matplotlib seaborn

# %%
# !pip install opencv-python

# %%
from skimage import data

image = data.camera()
pixelated = image[::10, ::10]
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(10, 5))
ax0.imshow(image)
ax1.imshow(pixelated) ;

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image, ImageDraw, ImageFilter

import warnings
warnings.filterwarnings('ignore')
I = Image.open("/lena.png")
I.show()
plt.imshow(np.asarray(I))
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from PIL import Image, ImageDraw, ImageFilter

import warnings
warnings.filterwarnings('ignore')

img = Image.open("/content/lena.jpg")
I2 = img.filter(ImageFilter.BoxBlur(3))

plt.imshow(np.asarray(I2))
plt.axis('off')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from PIL import Image, ImageDraw, ImageFilter

import warnings
warnings.filterwarnings('ignore')

img = cv2.imread("/content/lena.jpg")
I2 = cv2.blur(img, (3, 3))

plt.imshow(cv2.cvtColor(I2, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
